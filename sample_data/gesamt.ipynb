# %% [markdown]
# # Beispiel-Hospitationsprotokoll
# Dies ist ein Hospitationsprotokoll, basierend auf den Daten die von meiner Software (verfügbar unter https://github.com/MrCactus753/Classroom_Conversation_Measurer) gesammelt wurden. Zuerst zeige ich wie die Rohdaten gesammelt wurden, und anschließend lege ich die erhobenen Daten dar und werte sie aus. Hierbei werden sowohl die Operationen im Hintergrund angegeben, als auch Beschreibungen hierfür gegeben.

# %% [markdown]
# ## Initialisierung / Darstellung der Grunddaten:

# %%
import pandas as pd #importiert benötigte Module
import matplotlib.pyplot as plt #importiert benötigte Module

raw_data = pd.read_csv('gesamtdaten.csv').round(2)#importiert die Datei
nicer_data= raw_data.pivot(columns = 'role', values = 'time spoken')#spaltet / sortiert die Tabelle
dimensions =raw_data.shape
length = dimensions[0]-1
students = nicer_data['student'].dropna().sort_values().reset_index().drop(columns=['index'])#schönere Formattierung
teacher = nicer_data['teacher'].dropna().sort_values().reset_index().drop(columns=['index'])#schönere Formattierung
nobody = nicer_data['nobody'].dropna().sort_values().reset_index().drop(columns=['index'])#schönere Formattierung
raw_data# Dient lediglich der Darstellung der Daten
# Out:
#            role  time spoken
# 0       student         1.80
# 1       teacher        31.99
# 2       teacher        18.13
# 3       student         6.29
# 4       teacher        30.51
# 5       student         2.70
# 6       teacher         9.62
# 7       student         1.92
# 8       teacher        16.61
# 9       student         1.15
# 10      teacher        23.24
# 11      student         2.73
# 12      teacher         7.64
# 13      student         1.22
# 14      teacher         6.27
# 15      student         1.43
# 16      teacher         8.86
# 17      student         1.23
# 18      teacher         2.10
# 19      student         0.71
# 20      teacher         5.84
# 21      student         1.46
# 22      teacher        11.32
# 23      student         1.40
# 24      teacher        30.18
# 25       nobody        47.20
# 26      teacher        34.95
# 27      student         3.93
# 28      teacher         2.82
# 29      student         7.30
# ..          ...          ...
# 291     teacher        19.37
# 292     student         2.36
# 293     teacher         5.22
# 294     student         2.16
# 295     student        13.16
# 296     teacher        14.56
# 297     student         8.55
# 298     teacher         4.45
# 299     student        12.50
# 300     teacher         2.51
# 301     student         2.41
# 302     teacher         2.67
# 303     student        19.07
# 304     teacher         6.92
# 305     student         3.26
# 306     student         2.20
# 307     student         2.78
# 308     student         5.52
# 309     student         7.25
# 310     student        13.42
# 311     teacher         2.01
# 312     teacher        16.97
# 313     student         5.76
# 314     student         9.82
# 315     teacher        12.91
# 316      nobody        48.22
# 317     teacher        28.39
# 318      nobody       103.69
# 319     teacher        30.01
# 320  total time      6337.71
#
# [321 rows x 2 columns]

# %% [markdown]
# Damit die Daten verwendet werden können, muss zuerst die betreffende .csv-Datei geladen und zur weiteren Verarbeitung vorbereitet werden. Hierzu wird die Rohdatei in mehrere Unterlisten unterteilt damit die Daten ersichtlicher sind. Dies resultiert in der folgenden (sortierten) Tabelle (NaN = leeres Feld):

# %%
sorted_data = pd.concat([students,teacher,nobody], axis=1)
sorted_data
# Out:
#      student  teacher  nobody
# 0       0.61     0.63    3.13
# 1       0.71     1.35    7.00
# 2       0.76     1.45    7.05
# 3       1.05     1.57    8.70
# 4       1.15     1.94   14.66
# 5       1.22     1.98   16.13
# 6       1.23     2.01   17.93
# 7       1.29     2.10   47.20
# 8       1.40     2.12   48.22
# 9       1.43     2.13   58.53
# 10      1.46     2.51   62.86
# 11      1.49     2.51  103.69
# 12      1.70     2.56  125.77
# 13      1.77     2.61  138.41
# 14      1.80     2.67  142.35
# 15      1.86     2.78  162.12
# 16      1.91     2.82  200.00
# 17      1.92     2.93  304.73
# 18      1.95     3.00  341.01
# 19      2.05     3.16     NaN
# 20      2.10     3.17     NaN
# 21      2.13     3.72     NaN
# 22      2.16     3.89     NaN
# 23      2.20     4.00     NaN
# 24      2.35     4.03     NaN
# 25      2.36     4.37     NaN
# 26      2.37     4.45     NaN
# 27      2.40     4.48     NaN
# 28      2.41     4.52     NaN
# 29      2.41     4.88     NaN
# ..       ...      ...     ...
# 141    12.98      NaN     NaN
# 142    13.16      NaN     NaN
# 143    13.20      NaN     NaN
# 144    13.42      NaN     NaN
# 145    13.90      NaN     NaN
# 146    14.03      NaN     NaN
# 147    14.46      NaN     NaN
# 148    14.61      NaN     NaN
# 149    14.65      NaN     NaN
# 150    14.75      NaN     NaN
# 151    14.82      NaN     NaN
# 152    17.15      NaN     NaN
# 153    18.16      NaN     NaN
# 154    19.07      NaN     NaN
# 155    19.59      NaN     NaN
# 156    19.97      NaN     NaN
# 157    21.26      NaN     NaN
# 158    22.86      NaN     NaN
# 159    24.35      NaN     NaN
# 160    24.77      NaN     NaN
# 161    28.52      NaN     NaN
# 162    28.66      NaN     NaN
# 163    31.60      NaN     NaN
# 164    36.20      NaN     NaN
# 165    45.11      NaN     NaN
# 166    59.36      NaN     NaN
# 167    64.86      NaN     NaN
# 168    66.25      NaN     NaN
# 169   121.69      NaN     NaN
# 170   184.32      NaN     NaN
#
# [171 rows x 3 columns]

# %% [markdown]
# ## Auswertung der Daten
# Im nächsten Schritt, müssen die Daten ausgewertet werden um verständlich dargestellt zu werden. Hierbei werden mehrere Metriken verwendet. In erster Linie wird das Verhältnis zwischen den Redeanteilen von Schüler_innen und der Lehrperson dargestellt, gefolgt von der Darstellung der durchschnittlichen Redezeit.

# %%
solutions = pd.DataFrame({
    'Schüler':[students.sum(axis = 0),students.mean(),((students.sum()/raw_data.loc[length].at['time spoken'])*100)], 
    'Lehrer':[teacher.sum(), teacher.mean(),(teacher.sum()/raw_data.loc[length].at['time spoken'])*100],
    'Ruhe':[nobody.sum(),nobody.mean(),(nobody.sum()/raw_data.loc[length].at['time spoken'])*100]}, 
    index = ['Gesamte Zeit in Sekunden','Durchschnittliche Dauer in Sekunden', 'Anteil in Prozent'])
solutions
# Out:
#                                                                  Schüler  \
# Gesamte Zeit in Sekunden               student    1773.03
# dtype: float64
# Durchschnittliche Dauer in Sekunden  student    10.368596
# dtype: float64
# Anteil in Prozent                    student    27.975878
# dtype: float64
#
#                                                                   Lehrer  \
# Gesamte Zeit in Sekunden               teacher    2618.18
# dtype: float64
# Durchschnittliche Dauer in Sekunden  teacher    20.454531
# dtype: float64
# Anteil in Prozent                    teacher    41.311136
# dtype: float64
#
#                                                                    Ruhe
# Gesamte Zeit in Sekunden               nobody    1809.49
# dtype: float64
# Durchschnittliche Dauer in Sekunden  nobody    95.236316
# dtype: float64
# Anteil in Prozent                    nobody    28.551164
# dtype: float64

# %%
# Data to plot
labels = 'Schüler', 'Lehrer', 'Ruhe'
sizes = [(students.sum()/1530.65678)*100,(teacher.sum()/1530.65678)*100,(nobody.sum()/1530.65678)*100]
colors = ['gold', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode = explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %% [markdown]
# ## Kreation eines Häufigkeitshistograms

# %%
frequency_students = sorted_data['student'].round(0).value_counts()
frequency_teacher = sorted_data['teacher'].round(0).value_counts()
graph = pd.DataFrame()
graph['Schüler'] = frequency_students
graph['Lehrer'] = frequency_teacher
ax = graph.plot.hist(bins=15, alpha=0.3)
