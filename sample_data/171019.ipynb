# %% [markdown]
# # Hospitationsprotokoll
# Dies ist ein Hospitationsprotokoll, basierend auf den Daten die von meiner Software (verfügbar unter https://github.com/MrCactus753/Classroom_Conversation_Measurer) gesammelt wurden. Zuerst zeige ich wie die Rohdaten gesammelt wurden, und anschließend lege ich die erhobenen Daten dar und werte sie aus. Hierbei werden sowohl die Operationen im Hintergrund angegeben, als auch Beschreibungen hierfür gegeben.

# %% [markdown]
# ## Initialisierung / Darstellung der Grunddaten:

# %%
import pandas as pd #importiert benötigte Module
import matplotlib.pyplot as plt #importiert benötigte Module

raw_data = pd.read_csv('17_10_19_2c.csv').round(2)#importiert die Datei
nicer_data= raw_data.pivot(columns = 'role', values = 'time spoken')#spaltet / sortiert die Tabelle
dimensions =raw_data.shape
length = dimensions[0]-1
students = nicer_data['student'].dropna().sort_values().reset_index().drop(columns=['index'])#schönere Formattierung
teacher = nicer_data['teacher'].dropna().sort_values().reset_index().drop(columns=['index'])#schönere Formattierung
nobody = nicer_data['nobody'].dropna().sort_values().reset_index().drop(columns=['index'])#schönere Formattierung
raw_data# Dient lediglich der Darstellung der Daten
# Out:
#            role  time spoken
# 0       teacher         5.76
# 1       student         9.44
# 2       student        10.79
# 3       student         3.38
# 4       student         3.75
# 5       student         6.75
# 6       teacher        19.40
# 7       student         5.20
# 8       student        10.51
# 9       teacher        14.23
# 10      student         4.72
# 11      teacher         7.41
# 12      student        12.75
# 13      teacher         6.99
# 14      student         8.60
# 15      teacher         5.15
# 16      student         2.61
# 17      student         6.74
# 18      teacher        10.38
# 19      student         5.42
# 20      student         4.55
# 21      student         8.63
# 22      student         2.05
# 23      student         2.51
# 24      teacher        10.45
# 25      student         3.47
# 26      teacher        28.79
# 27      student         3.80
# 28      teacher         3.16
# 29      student         1.49
# ..          ...          ...
# 103     teacher        19.37
# 104     student         2.36
# 105     teacher         5.22
# 106     student         2.16
# 107     student        13.16
# 108     teacher        14.56
# 109     student         8.55
# 110     teacher         4.45
# 111     student        12.50
# 112     teacher         2.51
# 113     student         2.41
# 114     teacher         2.67
# 115     student        19.07
# 116     teacher         6.92
# 117     student         3.26
# 118     student         2.20
# 119     student         2.78
# 120     student         5.52
# 121     student         7.25
# 122     student        13.42
# 123     teacher         2.01
# 124     teacher        16.97
# 125     student         5.76
# 126     student         9.82
# 127     teacher        12.91
# 128      nobody        48.22
# 129     teacher        28.39
# 130      nobody       103.69
# 131     teacher        30.01
# 132  total time      1808.77
#
# [133 rows x 2 columns]

# %% [markdown]
# Damit die Daten verwendet werden können, muss zuerst die betreffende .csv-Datei geladen und zur weiteren Verarbeitung vorbereitet werden. Hierzu wird die Rohdatei in mehrere Unterlisten unterteilt damit die Daten ersichtlicher sind. Dies resultiert in der folgenden (sortierten) Tabelle (NaN = leeres Feld):

# %%
sorted_data = pd.concat([students,teacher,nobody], axis=1)
sorted_data
# Out:
#     student  teacher  nobody
# 0      1.49     1.45   48.22
# 1      1.70     2.01   62.86
# 2      1.86     2.51  103.69
# 3      1.91     2.61  142.35
# 4      1.95     2.67  200.00
# 5      2.05     3.16     NaN
# 6      2.16     3.89     NaN
# 7      2.20     4.03     NaN
# 8      2.36     4.37     NaN
# 9      2.40     4.45     NaN
# 10     2.41     4.52     NaN
# 11     2.48     4.96     NaN
# 12     2.51     5.15     NaN
# 13     2.58     5.22     NaN
# 14     2.61     5.76     NaN
# 15     2.78     5.87     NaN
# 16     3.17     6.17     NaN
# 17     3.25     6.51     NaN
# 18     3.26     6.92     NaN
# 19     3.29     6.99     NaN
# 20     3.38     7.41     NaN
# 21     3.47     7.55     NaN
# 22     3.67     8.60     NaN
# 23     3.71     9.26     NaN
# 24     3.73     9.87     NaN
# 25     3.75    10.38     NaN
# 26     3.80    10.45     NaN
# 27     4.14    11.12     NaN
# 28     4.22    12.91     NaN
# 29     4.32    13.93     NaN
# ..      ...      ...     ...
# 53     8.55      NaN     NaN
# 54     8.60      NaN     NaN
# 55     8.63      NaN     NaN
# 56     9.23      NaN     NaN
# 57     9.29      NaN     NaN
# 58     9.44      NaN     NaN
# 59     9.64      NaN     NaN
# 60     9.82      NaN     NaN
# 61    10.30      NaN     NaN
# 62    10.32      NaN     NaN
# 63    10.51      NaN     NaN
# 64    10.67      NaN     NaN
# 65    10.79      NaN     NaN
# 66    12.04      NaN     NaN
# 67    12.50      NaN     NaN
# 68    12.73      NaN     NaN
# 69    12.75      NaN     NaN
# 70    12.98      NaN     NaN
# 71    13.16      NaN     NaN
# 72    13.42      NaN     NaN
# 73    14.03      NaN     NaN
# 74    14.46      NaN     NaN
# 75    14.75      NaN     NaN
# 76    18.16      NaN     NaN
# 77    19.07      NaN     NaN
# 78    19.97      NaN     NaN
# 79    28.52      NaN     NaN
# 80    28.66      NaN     NaN
# 81    36.20      NaN     NaN
# 82    45.11      NaN     NaN
#
# [83 rows x 3 columns]

# %% [markdown]
# ## Auswertung der Daten
# Im nächsten Schritt, müssen die Daten ausgewertet werden um verständlich dargestellt zu werden. Hierbei werden mehrere Metriken verwendet. In erster Linie wird das Verhältnis zwischen den Redeanteilen von Schüler_innen und der Lehrperson dargestellt, gefolgt von der Darstellung der durchschnittlichen Redezeit.

# %%
solutions = pd.DataFrame({
    'Schüler':[students.sum(axis = 0),students.mean(),((students.sum()/raw_data.loc[length].at['time spoken'])*100)], 
    'Lehrer':[teacher.sum(), teacher.mean(),(teacher.sum()/raw_data.loc[length].at['time spoken'])*100],
    'Ruhe':[nobody.sum(),nobody.mean(),(nobody.sum()/raw_data.loc[length].at['time spoken'])*100]}, 
    index = ['Gesamte Zeit in Sekunden','Durchschnittliche Dauer in Sekunden', 'Anteil in Prozent'])
solutions
# Out:
#                                                                  Schüler  \
# Gesamte Zeit in Sekunden                student    687.12
# dtype: float64
# Durchschnittliche Dauer in Sekunden   student    8.278554
# dtype: float64
# Anteil in Prozent                    student    37.988246
# dtype: float64
#
#                                                                   Lehrer  \
# Gesamte Zeit in Sekunden                teacher    563.88
# dtype: float64
# Durchschnittliche Dauer in Sekunden  teacher    12.815455
# dtype: float64
# Anteil in Prozent                    teacher    31.174776
# dtype: float64
#
#                                                                    Ruhe
# Gesamte Zeit in Sekunden                nobody    557.12
# dtype: float64
# Durchschnittliche Dauer in Sekunden    nobody    111.424
# dtype: float64
# Anteil in Prozent                    nobody    30.801042
# dtype: float64

# %%
# Data to plot
labels = 'Schüler', 'Lehrer', 'Ruhe'
sizes = [(students.sum()/1530.65678)*100,(teacher.sum()/1530.65678)*100,(nobody.sum()/1530.65678)*100]
colors = ['gold', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode = explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %% [markdown]
# ## Kreation eines Häufigkeitshistograms

# %%
frequency_students = sorted_data['student'].round(0).value_counts()
frequency_teacher = sorted_data['teacher'].round(0).value_counts()
graph = pd.DataFrame()
graph['Schüler'] = frequency_students
graph['Lehrer'] = frequency_teacher
ax = graph.plot.hist(bins=15, alpha=0.3)
